# %% [markdown]
# <H1 style="text-align: center">Hidden Markov Models</H1>

# %%
#!pip install mchmm #install libaray
from google.colab import drive
# drive.mount('/content/drive') # ignore it if you don't use Google Colab
import numpy as np
import matplotlib.pyplot as plt
import mchmm as mc

# strings = []
# with open('COM3031/dict_eng.txt','r') as f:

print(strings)

# %%
import mchmm as mc

# TODO create a Hidden Markov Model (HMM)
# TODO train it using the Baum-Welch algorithm

# print: Initial State Probability Vector, Emission Probability Matrix, Transition Probability Matrix

# %%
# Interpret B_matrix

# %%
max_index_col = np.argmax(np.transpose(B_matrix),axis = 1)
plt.scatter(tab[:,0],max_index_col) # for visualization
# Adding labels
plt.xlabel("Observation Symbols")
plt.ylabel("Most Likely Hidden State")
plt.title("Most Likely Hidden State for Each Observation")

plt.grid()
plt.show()

# %%
# TODO: Use viterbi algorithm to find the best hidden sequence

# %%
# TODO: Visualize your results

# %%
# TODO: Use Forward Algorithm to compute the probability
